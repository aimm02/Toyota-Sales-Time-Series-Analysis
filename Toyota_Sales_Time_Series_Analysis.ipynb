# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('/content/penjualan_mobil_toyota.csv')

# %% [markdown]
# # Preprocessing

# %%
df.isnull().sum()
# Out:
# Bulan        0
# Penjualan    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Bulan'] = pd.to_datetime(df['Bulan'], format='%Y-%m')
print(df.head())
# Out:
#        Bulan  Penjualan
# 0 2011-01-01      27619
# 1 2011-02-01      25532
# 2 2011-03-01      32275
# 3 2011-04-01      21128
# 4 2011-05-01      19554

# %%
max_sales = df['Penjualan'].max()
max_row = df[df['Penjualan'] == max_sales].iloc[0]

# %%
min_sales = df['Penjualan'].min()
min_row = df[df['Penjualan'] == min_sales].iloc[0]

# %%
print(f"Penjualan Tahun Tertinggi : {max_yearly['Tahun']} dengan total {max_yearly['Penjualan']:,} unit.")
print(f"Penjualan Tahun Terendah : {min_yearly['Tahun']} dengan total {min_yearly['Penjualan']:,} unit.")
# Out:
# Penjualan Tahun Tertinggi : 2013 dengan total 434,232 unit.
# Penjualan Tahun Terendah : 2020 dengan total 161,256 unit.

# %% [markdown]
# # Feature Engineering

# %%
df['Tahun'] = df['Bulan'].dt.year

# %%
penjualan_tahunan = df.groupby('Tahun')['Penjualan'].sum().reset_index()
print(penjualan_tahunan)
# Out:
#     Tahun  Penjualan
# 0    2011     310674
# 1    2012     405414
# 2    2013     434232
# 3    2014     399119
# 4    2015     321818
# 5    2016     381570
# 6    2017     371332
# 7    2018     352161
# 8    2019     331797
# 9    2020     161256
# 10   2021     295768
# 11   2022     331410
# 12   2023     135473

# %%
max_yearly = penjualan_tahunan_full[penjualan_tahunan_full['Penjualan'] == penjualan_tahunan_full['Penjualan'].max()].iloc[0]
min_yearly = penjualan_tahunan_full[penjualan_tahunan_full['Penjualan'] == penjualan_tahunan_full['Penjualan'].min()].iloc[0]

# %% [markdown]
# # Visualisasi

# %%
plt.figure(figsize=(12, 6))
plt.bar(
    penjualan_tahunan['Tahun'].astype(str),
    penjualan_tahunan['Penjualan'],
    color='#33a02c'
)
plt.title('Total Penjualan Mobil Toyota per Tahun (2011 - 2023)', fontsize=16, fontweight='bold')
plt.xlabel('Tahun')
plt.ylabel('Total Penjualan (Unit)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle=':', alpha=0.6)
plt.tight_layout()
